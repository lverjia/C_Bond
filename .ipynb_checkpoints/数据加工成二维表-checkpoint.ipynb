# %%
import pandas as pd
datename = '180101To220825'
convdataname = '{}{}{}'.format('convdata_',datename,'.csv')
pricefilename = '{}{}{}'.format('data/price_',datename,'.pkl')
premfilename = '{}{}{}'.format('data/prem_',datename,'.pkl')
sizefilename = '{}{}{}'.format('data/size_',datename,'.pkl')
day_returnfilename = '{}{}{}'.format('data/day_return_',datename,'.pkl')
price100filename = '{}{}{}'.format('data/price100_',datename,'.pkl')
prem100filename = '{}{}{}'.format('data/prem100_',datename,'.pkl')
size100filename = '{}{}{}'.format('data/size100_',datename,'.pkl')

data=pd.read_csv(convdataname)
data  #查看基本信息
# Out:
#         Unnamed: 0  tickerBond secShortNameBond  tickerEqu   tradeDate  \
# 0                0      110030             格力转债     600185  2018-01-02
# 1                1      110030             格力转债     600185  2018-01-03
# 2                2      110030             格力转债     600185  2018-01-04
# 3                3      110030             格力转债     600185  2018-01-05
# 4                4      110030             格力转债     600185  2018-01-08
# ...            ...         ...              ...        ...         ...
# 273857      273857      128145             日丰转债       2953  2022-08-19
# 273858      273858      128145             日丰转债       2953  2022-08-22
# 273859      273859      128145             日丰转债       2953  2022-08-23
# 273860      273860      128145             日丰转债       2953  2022-08-24
# 273861      273861      128145             日丰转债       2953  2022-08-25
#
#         totalSize  remainSize  closePriceBond  bondPremRatio
# 0             9.8    9.774980         105.400        32.2523
# 1             9.8    9.774980         105.460        31.8705
# 2             9.8    9.774980         105.600        31.8179
# 3             9.8    9.774980         109.340        28.7189
# 4             9.8    9.774770         109.760        26.7404
# ...           ...         ...             ...            ...
# 273857        3.8    3.768341         153.500        10.1103
# 273858        3.8    3.768341         150.276        13.4137
# 273859        3.8    3.768341         149.899        12.9657
# 273860        3.8    3.768321         149.583         8.7213
# 273861        3.8    3.768321         143.979         7.0349
#
# [273862 rows x 9 columns]

# %%
len(data)
# Out:
# 273862

# %%
#接下来需要做的是构造一个收益率矩阵，列名为转债代码，行号为交易日期。
#我们首先来构造一个收盘价的矩阵
pricedf=data[['tickerBond','tradeDate','closePriceBond']]
pricedf=pricedf.set_index(['tradeDate','tickerBond']).unstack()['closePriceBond']
pricedf.index=pd.to_datetime(pricedf.index)
#pricedf.to_pickle(pricefilename)
pricedf
# Out:
# tickerBond  110030  110031  110032  110033  110034   110038  110039  110040  \
# tradeDate
# 2018-01-02  105.40  100.09  126.64  118.08  110.44  107.550  107.17  111.53
# 2018-01-03  105.46  100.37  127.53  120.01  112.74  110.000  108.00  112.31
# 2018-01-04  105.60  100.38  127.07  120.39  114.00  111.100  110.35  112.25
# 2018-01-05  109.34  101.40  130.14  123.89  114.00  112.570  112.95  113.29
# 2018-01-08  109.76  100.67  132.33  124.40  113.95  113.150  112.03  113.68
# ...            ...     ...     ...     ...     ...      ...     ...     ...
# 2022-08-19     NaN     NaN     NaN     NaN     NaN  130.649     NaN     NaN
# 2022-08-22     NaN     NaN     NaN     NaN     NaN  130.117     NaN     NaN
# 2022-08-23     NaN     NaN     NaN     NaN     NaN  128.444     NaN     NaN
# 2022-08-24     NaN     NaN     NaN     NaN     NaN  125.486     NaN     NaN
# 2022-08-25     NaN     NaN     NaN     NaN     NaN  124.387     NaN     NaN
#
# tickerBond  110041  110042  ...   128136   128137  128138  128139   128140  \
# tradeDate                   ...
# 2018-01-02     NaN     NaN  ...      NaN      NaN     NaN     NaN      NaN
# 2018-01-03     NaN     NaN  ...      NaN      NaN     NaN     NaN      NaN
# 2018-01-04     NaN     NaN  ...      NaN      NaN     NaN     NaN      NaN
# 2018-01-05     NaN     NaN  ...      NaN      NaN     NaN     NaN      NaN
# 2018-01-08     NaN     NaN  ...      NaN      NaN     NaN     NaN      NaN
# ...            ...     ...  ...      ...      ...     ...     ...      ...
# 2022-08-19     NaN     NaN  ...  117.999  135.000  120.97   293.0  177.000
# 2022-08-22     NaN     NaN  ...  118.777  138.030  121.23     NaN  174.650
# 2022-08-23     NaN     NaN  ...  118.660  138.131  121.98     NaN  170.200
# 2022-08-24     NaN     NaN  ...  116.100  134.813  120.31     NaN  158.400
# 2022-08-25     NaN     NaN  ...  116.062  132.621  119.77     NaN  160.699
#
# tickerBond   128141   128142   128143   128144   128145
# tradeDate
# 2018-01-02      NaN      NaN      NaN      NaN      NaN
# 2018-01-03      NaN      NaN      NaN      NaN      NaN
# 2018-01-04      NaN      NaN      NaN      NaN      NaN
# 2018-01-05      NaN      NaN      NaN      NaN      NaN
# 2018-01-08      NaN      NaN      NaN      NaN      NaN
# ...             ...      ...      ...      ...      ...
# 2022-08-19  152.414  113.900  136.100  124.000  153.500
# 2022-08-22  157.040  114.582  133.960  124.420  150.276
# 2022-08-23  151.020  114.250  136.849  123.566  149.899
# 2022-08-24  146.041  113.400  131.200  122.779  149.583
# 2022-08-25  143.826  112.700  128.500  123.239  143.979
#
# [1130 rows x 629 columns]

# %%
len(pricedf)
# Out:
# 1130

# %%
#构造收益率矩阵
day_return=pricedf.pct_change().shift(-1)
#day_return.to_pickle(day_returnfilename)
day_return
# Out:
# tickerBond    110030    110031    110032    110033    110034    110038  \
# tradeDate
# 2018-01-02  0.000569  0.002797  0.007028  0.016345  0.020826  0.022780
# 2018-01-03  0.001328  0.000100 -0.003607  0.003166  0.011176  0.010000
# 2018-01-04  0.035417  0.010161  0.024160  0.029072  0.000000  0.013231
# 2018-01-05  0.003841 -0.007199  0.016828  0.004117 -0.000439  0.005152
# 2018-01-08 -0.005284 -0.002682 -0.013829 -0.000482  0.004651  0.000884
# ...              ...       ...       ...       ...       ...       ...
# 2022-08-19  0.000000  0.000000  0.000000  0.000000  0.000000 -0.004072
# 2022-08-22  0.000000  0.000000  0.000000  0.000000  0.000000 -0.012858
# 2022-08-23  0.000000  0.000000  0.000000  0.000000  0.000000 -0.023029
# 2022-08-24  0.000000  0.000000  0.000000  0.000000  0.000000 -0.008758
# 2022-08-25       NaN       NaN       NaN       NaN       NaN       NaN
#
# tickerBond    110039    110040  110041  110042  ...    128136    128137  \
# tradeDate                                       ...
# 2018-01-02  0.007745  0.006994     NaN     NaN  ...       NaN       NaN
# 2018-01-03  0.021759 -0.000534     NaN     NaN  ...       NaN       NaN
# 2018-01-04  0.023561  0.009265     NaN     NaN  ...       NaN       NaN
# 2018-01-05 -0.008145  0.003442     NaN     NaN  ...       NaN       NaN
# 2018-01-08 -0.008569 -0.018209     NaN     NaN  ...       NaN       NaN
# ...              ...       ...     ...     ...  ...       ...       ...
# 2022-08-19  0.000000  0.000000     0.0     0.0  ...  0.006593  0.022444
# 2022-08-22  0.000000  0.000000     0.0     0.0  ... -0.000985  0.000732
# 2022-08-23  0.000000  0.000000     0.0     0.0  ... -0.021574 -0.024021
# 2022-08-24  0.000000  0.000000     0.0     0.0  ... -0.000327 -0.016260
# 2022-08-25       NaN       NaN     NaN     NaN  ...       NaN       NaN
#
# tickerBond    128138  128139    128140    128141    128142    128143  \
# tradeDate
# 2018-01-02       NaN     NaN       NaN       NaN       NaN       NaN
# 2018-01-03       NaN     NaN       NaN       NaN       NaN       NaN
# 2018-01-04       NaN     NaN       NaN       NaN       NaN       NaN
# 2018-01-05       NaN     NaN       NaN       NaN       NaN       NaN
# 2018-01-08       NaN     NaN       NaN       NaN       NaN       NaN
# ...              ...     ...       ...       ...       ...       ...
# 2022-08-19  0.002149     0.0 -0.013277  0.030352  0.005988 -0.015724
# 2022-08-22  0.006187     0.0 -0.025480 -0.038334 -0.002897  0.021566
# 2022-08-23 -0.013691     0.0 -0.069330 -0.032969 -0.007440 -0.041279
# 2022-08-24 -0.004488     0.0  0.014514 -0.015167 -0.006173 -0.020579
# 2022-08-25       NaN     NaN       NaN       NaN       NaN       NaN
#
# tickerBond    128144    128145
# tradeDate
# 2018-01-02       NaN       NaN
# 2018-01-03       NaN       NaN
# 2018-01-04       NaN       NaN
# 2018-01-05       NaN       NaN
# 2018-01-08       NaN       NaN
# ...              ...       ...
# 2022-08-19  0.003387 -0.021003
# 2022-08-22 -0.006864 -0.002509
# 2022-08-23 -0.006369 -0.002108
# 2022-08-24  0.003747 -0.037464
# 2022-08-25       NaN       NaN
#
# [1130 rows x 629 columns]

# %%
#溢价率矩阵
premdf=data[['tickerBond','tradeDate','bondPremRatio']]
premdf=premdf.set_index(['tradeDate','tickerBond']).unstack()['bondPremRatio']
premdf.index=pd.to_datetime(premdf.index)
#premdf.to_pickle(premfilename)
premdf
# Out:
# tickerBond   110030    110031  110032  110033   110034   110038  110039  \
# tradeDate
# 2018-01-02  32.2523   97.8684 -0.7452  1.8888   5.9766  15.2441  5.5124
# 2018-01-03  31.8705   96.4259  0.0578  3.5541   8.4646  13.0295  7.3602
# 2018-01-04  31.8179   96.7153  0.0137  3.8820   9.2229  14.1312  7.4399
# 2018-01-05  28.7189   98.2603  0.8279  3.4569   9.9625  15.5835  7.5325
# 2018-01-08  26.7404  101.7170 -0.4846  3.1010  11.0712  14.2636  9.0756
# ...             ...       ...     ...     ...      ...      ...     ...
# 2022-08-19      NaN       NaN     NaN     NaN      NaN  20.9594     NaN
# 2022-08-22      NaN       NaN     NaN     NaN      NaN  21.2077     NaN
# 2022-08-23      NaN       NaN     NaN     NaN      NaN  23.2368     NaN
# 2022-08-24      NaN       NaN     NaN     NaN      NaN  22.8897     NaN
# 2022-08-25      NaN       NaN     NaN     NaN      NaN  22.4468     NaN
#
# tickerBond  110040  110041  110042  ...   128136   128137    128138  128139  \
# tradeDate                           ...
# 2018-01-02  4.6499     NaN     NaN  ...      NaN      NaN       NaN     NaN
# 2018-01-03  6.7098     NaN     NaN  ...      NaN      NaN       NaN     NaN
# 2018-01-04  6.8284     NaN     NaN  ...      NaN      NaN       NaN     NaN
# 2018-01-05  7.8774     NaN     NaN  ...      NaN      NaN       NaN     NaN
# 2018-01-08  7.5401     NaN     NaN  ...      NaN      NaN       NaN     NaN
# ...            ...     ...     ...  ...      ...      ...       ...     ...
# 2022-08-19     NaN     NaN     NaN  ...  82.2043  34.6563  137.3307  7.3896
# 2022-08-22     NaN     NaN     NaN  ...  78.7225  35.7047  142.7486     NaN
# 2022-08-23     NaN     NaN     NaN  ...  78.5930  40.3828  143.4774     NaN
# 2022-08-24     NaN     NaN     NaN  ...  82.9406  42.7768  148.3978     NaN
# 2022-08-25     NaN     NaN     NaN  ...  77.7872  40.0767  142.1311     NaN
#
# tickerBond   128140   128141   128142   128143   128144   128145
# tradeDate
# 2018-01-02      NaN      NaN      NaN      NaN      NaN      NaN
# 2018-01-03      NaN      NaN      NaN      NaN      NaN      NaN
# 2018-01-04      NaN      NaN      NaN      NaN      NaN      NaN
# 2018-01-05      NaN      NaN      NaN      NaN      NaN      NaN
# 2018-01-08      NaN      NaN      NaN      NaN      NaN      NaN
# ...             ...      ...      ...      ...      ...      ...
# 2022-08-19  17.6706   9.8081  90.3505  39.7514  39.2978  10.1103
# 2022-08-22  19.6921  11.6523  90.2805  44.1154  36.2173  13.4137
# 2022-08-23  19.2948   9.1551  90.5893  44.3945  33.7139  12.9657
# 2022-08-24  18.2022   9.5482  93.0212  44.2172  36.2859   8.7213
# 2022-08-25  20.1916   7.8350  90.2458  44.7774  31.4549   7.0349
#
# [1130 rows x 629 columns]

# %%
#余额矩阵
sizedf=data[['tickerBond','tradeDate','remainSize']]
sizedf=sizedf.set_index(['tradeDate','tickerBond']).unstack()['remainSize']
sizedf.index=pd.to_datetime(sizedf.index)
#sizedf.to_pickle(sizefilename)
sizedf
# Out:
# tickerBond   110030     110031     110032    110033     110034    110038  \
# tradeDate
# 2018-01-02  9.77498  23.994843  43.236470  14.62674  14.993263  8.431600
# 2018-01-03  9.77498  23.994843  43.120792  14.62674  14.993263  8.431600
# 2018-01-04  9.77498  23.994843  43.046653  14.62674  14.993263  8.431600
# 2018-01-05  9.77498  23.994843  43.043384  14.62672  14.993263  8.431600
# 2018-01-08  9.77477  23.994843  42.124041  14.62671  14.993263  8.431600
# ...             ...        ...        ...       ...        ...       ...
# 2022-08-19      NaN        NaN        NaN       NaN        NaN  6.301665
# 2022-08-22      NaN        NaN        NaN       NaN        NaN  6.301665
# 2022-08-23      NaN        NaN        NaN       NaN        NaN  6.301665
# 2022-08-24      NaN        NaN        NaN       NaN        NaN  6.301665
# 2022-08-25      NaN        NaN        NaN       NaN        NaN  6.301665
#
# tickerBond  110039  110040  110041  110042  ...     128136    128137  \
# tradeDate                                   ...
# 2018-01-02    16.0    18.0     NaN     NaN  ...        NaN       NaN
# 2018-01-03    16.0    18.0     NaN     NaN  ...        NaN       NaN
# 2018-01-04    16.0    18.0     NaN     NaN  ...        NaN       NaN
# 2018-01-05    16.0    18.0     NaN     NaN  ...        NaN       NaN
# 2018-01-08    16.0    18.0     NaN     NaN  ...        NaN       NaN
# ...            ...     ...     ...     ...  ...        ...       ...
# 2022-08-19     NaN     NaN     NaN     NaN  ...  29.992931  5.994073
# 2022-08-22     NaN     NaN     NaN     NaN  ...  29.992931  5.994073
# 2022-08-23     NaN     NaN     NaN     NaN  ...  29.992931  5.994073
# 2022-08-24     NaN     NaN     NaN     NaN  ...  29.992931  5.994073
# 2022-08-25     NaN     NaN     NaN     NaN  ...  29.992931  5.994073
#
# tickerBond    128138    128139     128140     128141    128142    128143  \
# tradeDate
# 2018-01-02       NaN       NaN        NaN        NaN       NaN       NaN
# 2018-01-03       NaN       NaN        NaN        NaN       NaN       NaN
# 2018-01-04       NaN       NaN        NaN        NaN       NaN       NaN
# 2018-01-05       NaN       NaN        NaN        NaN       NaN       NaN
# 2018-01-08       NaN       NaN        NaN        NaN       NaN       NaN
# ...              ...       ...        ...        ...       ...       ...
# 2022-08-19  4.199084  0.359963  10.896371  12.701485  7.179784  2.441972
# 2022-08-22  4.199084       NaN  10.896341  12.701485  7.179784  2.441972
# 2022-08-23  4.199084       NaN  10.896341  12.701485  7.179784  2.441972
# 2022-08-24  4.199084       NaN  10.896321  12.701485  7.179784  2.441972
# 2022-08-25  4.199084       NaN  10.896321  12.701485  7.179784  2.441972
#
# tickerBond    128144    128145
# tradeDate
# 2018-01-02       NaN       NaN
# 2018-01-03       NaN       NaN
# 2018-01-04       NaN       NaN
# 2018-01-05       NaN       NaN
# 2018-01-08       NaN       NaN
# ...              ...       ...
# 2022-08-19  9.794158  3.768341
# 2022-08-22  9.794158  3.768341
# 2022-08-23  9.794158  3.768341
# 2022-08-24  9.794158  3.768321
# 2022-08-25  9.794158  3.768321
#
# [1130 rows x 629 columns]
